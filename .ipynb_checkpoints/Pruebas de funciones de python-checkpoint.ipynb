# %%
import models.database_model as datamodel
import pandas as pd

# %%
db = datamodel.database('localhost','root','Adonispili2','imss_035')
db.connection()

# %%
sql = '''
            SELECT Nombre_Encuesta, Descripcion_seccion,  Descripcion_Pregunta, IdPregunta,
            group_concat(respuestas.Descripcion separator ',' ) as Respuestas , 
            group_concat(respuestas.Ponderacion separator ',' ) as Ponderacion
            FROM encuesta 
            INNER JOIN pregunta
            on encuesta.IdEncuesta = pregunta.Encuesta_IdEncuesta
            INNER JOIN grupo_respuestas
            on pregunta.Grupo_Respuestas_idGrupo_Respuestas = grupo_respuestas.idGrupo_Respuestas
            INNER JOIN respuestas
            on grupo_respuestas.idGrupo_Respuestas = respuestas.Grupo_Respuestas_idGrupo_Respuestas
            where IdEncuesta = 2
            group by IdPregunta;
          '''

# %%
result = db.execute_query(sql)
result
#df= pd.DataFrame(result)
#df2 = pd.DataFrame()
# Out:
# [{'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Mi trabajo me exige hacer mucho esfuerzo físico',
#   'IdPregunta': 21,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Me preocupa sufrir un accidente en mi trabajo',
#   'IdPregunta': 22,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Considero que las actividades que realizo son peligrosas',
#   'IdPregunta': 23,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Por la cantidad de trabajo que tengo debo quedarme tiempo adicional a mi turno',
#   'IdPregunta': 24,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Por la cantidad de trabajo que tengo debo trabajar sin parar ',
#   'IdPregunta': 25,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Considero que es necesario mantener un ritmo de trabajo acelerado',
#   'IdPregunta': 26,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Mi trabajo exige que esté muy concentrado ',
#   'IdPregunta': 27,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Mi trabajo requiere que memorice mucha información',
#   'IdPregunta': 28,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Mi trabajo exige que atienda varios asuntos al mismo tiempo',
#   'IdPregunta': 29,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'En mi trabajo soy responsable de cosas de mucho valor',
#   'IdPregunta': 30,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Respondo ante mi jefe por los resultados de toda mi área de trabajo',
#   'IdPregunta': 31,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'En mi trabajo me dan órdenes contradictorias',
#   'IdPregunta': 32,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Considero que en mi trabajo me piden hacer cosas innecesarias',
#   'IdPregunta': 33,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Trabajo horas extras más de tres veces a la semana',
#   'IdPregunta': 34,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Mi trabajo me exige laborar en días de descanso, festivos o fines de semana',
#   'IdPregunta': 35,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Considero que el tiempo en el trabajo es mucho y perjudica mis actividades familiares o personales',
#   'IdPregunta': 36,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Pienso en las actividades familiares o personales cuando estoy en mi trabajo',
#   'IdPregunta': 37,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Mi trabajo permite que desarrolle nuevas habilidades ',
#   'IdPregunta': 38,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'En mi trabajo puedo aspirar a un mejor puesto',
#   'IdPregunta': 39,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Durante mi jornada de trabajo puedo tomar pausas cuando las necesito',
#   'IdPregunta': 40,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Puedo decidir la velocidad a la que realizo mis actividades en mi trabajo',
#   'IdPregunta': 41,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Puedo cambiar el orden de las actividades que realizo en mi trabajo',
#   'IdPregunta': 42,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Me informan con claridad cuáles son mis funciones',
#   'IdPregunta': 43,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Me explican claramente los resultados que debo obtener en mi trabajo',
#   'IdPregunta': 44,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Me informan con quién puedo resolver problemas o asuntos de trabajo',
#   'IdPregunta': 45,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Me permiten asistir a capacitaciones relacionadas con mi trabajo',
#   'IdPregunta': 46,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Recibo capacitación útil para hacer mi trabajo',
#   'IdPregunta': 47,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Mi jefe tiene en cuenta mis puntos de vista y opiniones',
#   'IdPregunta': 48,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Mi jefe ayuda a solucionar los problemas que se presentan en el trabajo',
#   'IdPregunta': 49,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Puedo confiar en mis compañeros de trabajo',
#   'IdPregunta': 50,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Cuando tenemos que realizar trabajo de equipo los compañeros colaboran',
#   'IdPregunta': 51,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Mis compañeros de trabajo me ayudan cuando tengo dificultades',
#   'IdPregunta': 52,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'En mi trabajo puedo expresarme libremente sin interrupciones',
#   'IdPregunta': 53,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '0,1,2,3,4'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Recibo críticas constantes a mi persona y/o trabajo',
#   'IdPregunta': 54,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Recibo burlas, calumnias, difamaciones, humillaciones o ridiculizaciones',
#   'IdPregunta': 55,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Se ignora mi presencia o se me excluye de las reuniones de trabajo y en la toma de decisiones',
#   'IdPregunta': 56,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Se manipulan las situaciones de trabajo para hacerme parecer un mal trabajador',
#   'IdPregunta': 57,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Se ignoran mis éxitos laborales y se atribuyen a otros trabajadores',
#   'IdPregunta': 58,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Me bloquean o impiden las oportunidades que tengo para obtener ascenso o mejora en mi trabajo',
#   'IdPregunta': 59,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'He presenciado actos de violencia en mi centro de trabajo',
#   'IdPregunta': 60,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Atiendo clientes o usuarios muy enojados',
#   'IdPregunta': 61,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Mi trabajo me exige atender personas muy necesitadas de ayuda o enfermas',
#   'IdPregunta': 62,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Para hacer mi trabajo debo demostrar sentimientos distintos a los míos',
#   'IdPregunta': 63,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Comunican tarde los asuntos de trabajo',
#   'IdPregunta': 64,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Dificultan el logro de los resultados del trabajo',
#   'IdPregunta': 65,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'},
#  {'Nombre_Encuesta': 'Guía de Referencia II IDENTIFICACIÓN Y ANÁLISIS DE LOS FACTORES DE RIESGO PSICOSOCIAL',
#   'Descripcion_seccion': None,
#   'Descripcion_Pregunta': 'Ignoran las sugerencias para mejorar su trabajo',
#   'IdPregunta': 66,
#   'Respuestas': 'SIEMPRE,CASI SIEMPRE,ALGUNAS VECES,CASI NUNCA,NUNCA',
#   'Ponderacion': '4,3,2,1,0'}]

# %%
data = {
    result[0]['Nombre_Encuesta']:{
        result[0]['Descripcion_seccion']:{
             'preguntas':{
            
             }   
        }
        
       
    }
}



seccion = ""
count = 1
for row in result:
  
    if row['Descripcion_seccion'] != None and row['Descripcion_seccion'] != seccion:
        print('Descripcion_seccion: ' + row['Descripcion_seccion'] + "  seccion:  " + seccion  )
        print('____________________________________________________')
        print('iteracion numero: ', count)
        #print(data[row['Nombre_Encuesta']][row['Descripcion_seccion']] )
        if  row['Descripcion_seccion'] in data[row['Nombre_Encuesta']]:
            data[row['Nombre_Encuesta']][row['Descripcion_seccion']]['preguntas'][row['Descripcion_Pregunta']]={
                
                    'respuestas':row['Respuestas'].split(','),
                    'ponderacion':row['Ponderacion'].split(',')
            }
        else:
            data[row['Nombre_Encuesta']][row['Descripcion_seccion']]= {
                'preguntas':{
                     row['Descripcion_Pregunta']: {
                        'respuestas':row['Respuestas'].split(','),
                        'ponderacion':row['Ponderacion'].split(',') 
                    }
                    
                }
                
            }
                            
            
        seccion = row['Descripcion_seccion']
        print(data)
    
    else:
        print('iteracion numero: ', count)
        print(data)
        data[row['Nombre_Encuesta']][row['Descripcion_seccion']]['preguntas'][row['Descripcion_Pregunta']]={           
                    'respuestas':row['Respuestas'].split(','),
                    'ponderacion':row['Ponderacion'].split(',')
              }
    count +=1
data
# Out:
#   File "<ipython-input-5-1e9dc54ca838>", line 27
#     'respuestas':row['Respuestas'].extend('ponderacion':row['Ponderacion'].split(','))
#                                                        ^
# SyntaxError: invalid syntax

# %%
data['Guía de Referencia I  EJEMPLO DE CUESTIONARIO PARA IDENTIFICAR A LOS TRABAJADORES QUE FUERON SUJETOS A ACONTECIMIENTOS TRAUMÁTICOS SEVEROS']={          
                    "SECCION1":{
                        'preguntas':{
                            'pregunta': "COSA1",
                            'respuestas': "COSA2",
                            'ponderacion': "COSA3"
                        }
                    }      
                }

# %%
data

# %%
#df.info 
#df.describe()
#df.head()
#df.tail() 
#df.query('Nombre_Encuesta == `Descripcion_seccion`')
#df[df.NombreEncuesta == df['Descripcion_seccion']]

# %%
data = {}

data.update({
    result[0]["Nombre_Encuesta"]:{}
})
data.update({
    result[0]["Nombre_Encuesta"]:{
       result[0]["Descripcion_seccion"]:{
            "Pregunta":result[0]["Descripcion_Pregunta"],
            "Respuesta": result[0]["Respuestas"],
            "Ponderacion": result[0]["Ponderacion"]
        }
    }
})

# %%
for i in result:
    print(i["Descripcion_seccion"],i["Descripcion_Pregunta"])

# %%
{'Nombre_Encuesta': 'Guía de Referencia I  EJEMPLO DE CUESTIONARIO PARA IDENTIFICAR A LOS TRABAJADORES QUE FUERON SUJETOS A ACONTECIMIENTOS TRAUMÁTICOS SEVEROS', 
 'Descripcion_seccion': 'I.- Acontecimiento traumático severo', 
 'Descripcion_Pregunta': 'Actos violentos que derivaron en lesiones graves?', 
 'Respuestas': 'SI,NO', 
 'Ponderacion': None}

# %%
_split = "si,no"
_split =_split.split(',')
_split

# %%
import json
